# %% [markdown]
# ## Battle of the Neighborhoods - hotel edition

# %% [markdown]
# There are several hotels in Bangkok, in different areas. The objective here is to find the most suitable area for a new 5* hotel. What we want to understand is:
#
# * Where are 5 stars hotels located?
# * What are the similarities between the various 5 stars hotels?
# * Is there a common pattern for success based on the neighbourhood facilities?
#
# After this exploratory part, we will proceed to analyze hotel density per area and understand where we can open a new hotel.
#
# * What is the best location to open a new 5 stars hotel?

# %% [markdown]
# ### Tools for the job

# %% [markdown]
# We will use different tools.
#
# a. Exploratory part:
#
#    * folium
#    * open data related to Bangkok neighbourhoods
#    * requests and foursquare API to gather hotel data
#    * for each 5 star hotel, we will analyze the surroundings and understand what is the pattern in a hotel's location.
#
# b. Analysis
#
#    * TBD

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %%
# alternate scraping
url = 'https://en.wikipedia.org/w/index.php?title=List_of_districts_of_Bangkok&oldid=884382933'
response = requests.get(url)
# make the soup
soup = BeautifulSoup(response.text)
# find table
table = soup.find("table", {"class": "wikitable"})
rows = table.find_all('tr')[1:]
rows[0]
# Out:
# <tr>
# <td><a href="/wiki/Bang_Bon_District" title="Bang Bon District">Bang Bon</a></td>
# <td>50</td>
# <td>บางบอน</td>
# <td align="right">105,161</td>
# <td>4
# </td>
# <td>NA
# </td>
# <td>NA
# </td></tr>

# %%
# build df from table
cols = ['Neighborhood', 'Code', 'Thai','Population', 'Subdistricts', 'Latitude', 'Longitude'] 
#Initialize df
df = pd.DataFrame(columns=cols)

# %%
for i in range(len(rows)):
    df.loc[i] = [td.text.strip() for td in rows[i].find_all('td')]

# %%
df.head()
# Out:
#     Neighborhood Code       Thai Population Subdistricts   Latitude  \
# 0       Bang Bon   50     บางบอน    105,161            4         NA
# 1      Bang Kapi   06    บางกะปิ    148,465            2  13.765833
# 2      Bang Khae   40      บางแค    191,781            4  13.696111
# 3      Bang Khen   05     บางเขน    189,539            2  13.873889
# 4  Bang Kho Laem   31  บางคอแหลม     94,956            3  13.693333
#
#     Longitude
# 0          NA
# 1  100.647778
# 2  100.409444
# 3  100.596389
# 4    100.5025

# %%
df = df.drop(['Code', 'Thai', 'Population', 'Subdistricts'], axis=1)
df = df.drop(df[df.Latitude == 'NA'].index)
df = df.rename(columns={'Latitude':'latitude', 'Longitude':'longitude'})
df['latitude'] = pd.to_numeric(df['latitude'], errors='ignore')
df['longitude'] = pd.to_numeric(df['longitude'], errors='ignore')
df.head()
# Out:
#       Neighborhood   latitude   longitude
# 1        Bang Kapi  13.765833  100.647778
# 2        Bang Khae  13.696111  100.409444
# 3        Bang Khen  13.873889  100.596389
# 4    Bang Kho Laem  13.693333  100.502500
# 5  Bang Khun Thian  13.660833  100.435833

# %%
# Bangkok map
bkk_lat = 13.7563
bkk_lon = 100.5018
bkk = folium.Map(location=[bkk_lat, bkk_lon], zoom_start=10)
bkk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Let's load neighbourhood data for later use
bkk_hoods = r'adm2_greaterBK_hD4.json'

# %% [markdown]
# Now add markers to map

# %%
# add markers to map
for lat, lng, neighborhood in zip(df['latitude'], df['longitude'], df['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(bkk)  
    
bkk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Load foursquare credentials

CLIENT_ID = 'ZQCVWU4MH0JBSW2K03ME3T2GATLO2EF5PWQ25JFHSZ1UYZLM' # your Foursquare ID
CLIENT_SECRET = 'VMTDMOCYHACWG2N45IJ0YP2EY4AI2M2QPIY1VMFFPJ4XHDEF' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentials are loaded')
# Out:
# Your credentials are loaded

# %%
# now let's isolate a sample neighborhood, Bang Rak

hood_latitude = df.loc[30, 'latitude'] 
hood_longitude = df.loc[30, 'longitude'] 

hood_name = df.loc[30, 'Neighborhood'] 

print('Latitude and longitude values of {} are {}, {}.'.format(hood_name, 
                                                               hood_latitude, 
                                                               hood_longitude))
# Out:
# Latitude and longitude values of Phasi Charoen are 13.714722, 100.43722199999999.

# %%
# now let's search hotels. Build a URL:

# type your answer here

search_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query=hotel'.format(CLIENT_ID, CLIENT_SECRET, hood_latitude, hood_longitude, VERSION, 500, 100)

# %%
search_results = requests.get(search_url).json()
search_results
# Out:
# {'meta': {'code': 200, 'requestId': '5c6faf811ed2196e4aa41b29'},
#  'response': {'venues': [{'id': '4b0587f6f964a5200da922e3',
#     'name': 'Shangri-La Hotel, Bangkok',
#     'location': {'address': '89 Soi Charoen Krung 42/1',
#      'lat': 13.721573379038752,
#      'lng': 100.51381182368625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.721573379038752,
#        'lng': 100.51381182368625}],
#      'distance': 8317,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['89 Soi Charoen Krung 42/1',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '32930345'},
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4b0587f6f964a52013a922e3',
#     'name': 'Dusit Thani Bangkok (โรงแรมดุสิตธานี กรุงเทพฯ)',
#     'location': {'address': '946 Rama IV Rd',
#      'lat': 13.728431972601872,
#      'lng': 100.53718961295608,
#      'distance': 10917,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['946 Rama IV Rd',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4c20b858d8b5b7132385dbec',
#     'name': 'Siam Kempinski Hotel Bangkok',
#     'location': {'address': '991/9 Rama I Rd',
#      'lat': 13.748260167423403,
#      'lng': 100.53507371971705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.748260167423403,
#        'lng': 100.53507371971705}],
#      'distance': 11220,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['991/9 Rama I Rd',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '52df211311d2853599f61940',
#     'name': 'AVANI Riverside Bangkok Hotel',
#     'location': {'address': '257 Charoen Nakhon Rd',
#      'lat': 13.704950425982187,
#      'lng': 100.49142472911906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.704950425982187,
#        'lng': 100.49142472911906}],
#      'distance': 5961,
#      'postalCode': '10600',
#      'cc': 'TH',
#      'city': 'ธนบุรี',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['257 Charoen Nakhon Rd',
#       'ธนบุรี',
#       'กรุงเทพมหานคร 10600',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4b6bec9ef964a520bb1c2ce3',
#     'name': 'The Athenee Hotel',
#     'location': {'address': '61 Wireless Road (Witthayu), Lumpini, Pathumwan, Bangkok',
#      'lat': 13.741354108778376,
#      'lng': 100.547775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.741354108778376,
#        'lng': 100.547775}],
#      'distance': 12317,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['61 Wireless Road (Witthayu), Lumpini, Pathumwan, Bangkok',
#       'พระนคร',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4bb021b9f964a520e8383ce3',
#     'name': 'Renaissance Bangkok Ratchaprasong Hotel',
#     'location': {'address': '518/8 Ploenchit Road, Lumphini',
#      'lat': 13.742292993749796,
#      'lng': 100.54183381349185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.742292993749796,
#        'lng': 100.54183381349185}],
#      'distance': 11721,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'neighborhood': 'Lumphini',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['518/8 Ploenchit Road, Lumphini',
#       'พระนคร',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '131922330'},
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4c1f60558b3aa593e6549d5f',
#     'name': 'Baiyoke Sky Hotel',
#     'location': {'address': '222 Ratchaprarop Rd',
#      'crossStreet': 'Soi 3',
#      'lat': 13.754506691115248,
#      'lng': 100.5403196811676,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.754506691115248,
#        'lng': 100.5403196811676}],
#      'distance': 11996,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'ราชเทวี',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['222 Ratchaprarop Rd (Soi 3)',
#       'ราชเทวี',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4b0587f6f964a5200ca922e3',
#     'name': 'JW Marriott Hotel Bangkok',
#     'location': {'address': '4 Sukhumvit Road, Khlong Toei',
#      'lat': 13.741855049891672,
#      'lng': 100.55195242166519,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.741855049891672,
#        'lng': 100.55195242166519}],
#      'distance': 12769,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['4 Sukhumvit Road, Khlong Toei',
#       'พระนคร',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '131925827'},
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4bc8edc0762beee171b63d38',
#     'name': 'Zenith Sukhumvit Hotel Bangkok',
#     'location': {'address': '29 Sukhumvit 3',
#      'lat': 13.745082311611347,
#      'lng': 100.55334684083924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.745082311611347,
#        'lng': 100.55334684083924}],
#      'distance': 13004,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'วัฒนา',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['29 Sukhumvit 3',
#       'วัฒนา',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '172504234'},
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4b0587f6f964a52022a922e3',
#     'name': 'Royal Orchid Sheraton Hotel & Towers (โรงแรมรอยัลออคิดเชอราตัน)',
#     'location': {'address': '2 Charoen Krung 30',
#      'lat': 13.729053,
#      'lng': 100.513574,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.729053,
#        'lng': 100.513574}],
#      'distance': 8409,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['2 Charoen Krung 30',
#       'พระนคร',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4beb71e462c0c928253ee2d4',
#     'name': 'Pathumwan Princess Hotel (โรงแรมปทุมวันปริ๊นเซส)',
#     'location': {'address': '444 Phaya Thai Rd',
#      'crossStreet': 'at MBK Center',
#      'lat': 13.743293722821637,
#      'lng': 100.52978186870968,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.743293722821637,
#        'lng': 100.52978186870968}],
#      'distance': 10502,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['444 Phaya Thai Rd (at MBK Center)',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4d39126a8cd16ea8e74cbfe2',
#     'name': 'Bangkok Palace Hotel (โรงแรมบางกอกพาเลส)',
#     'location': {'address': '1091/336 Phetchaburi Rd',
#      'crossStreet': 'at Nikhom Makkasan Rd',
#      'lat': 13.752572176231642,
#      'lng': 100.54745539578671,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.752572176231642,
#        'lng': 100.54745539578671}],
#      'distance': 12642,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'ราชเทวี',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['1091/336 Phetchaburi Rd (at Nikhom Makkasan Rd)',
#       'ราชเทวี',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4e4f78847d8bd425e4900fed',
#     'name': 'Astera Sathorn Hotel',
#     'location': {'address': '143',
#      'crossStreet': 'Sathorn Tai',
#      'lat': 13.718180333021602,
#      'lng': 100.5164426258604,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.718180333021602,
#        'lng': 100.5164426258604}],
#      'distance': 8575,
#      'postalCode': '10120',
#      'cc': 'TH',
#      'city': 'Yannawa',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['143 (Sathorn Tai)',
#       'Yannawa',
#       'กรุงเทพมหานคร 10120',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '77251601'},
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4bc8ede0762beee17cb63d38',
#     'name': 'Tongtara Riverview Hotel Bangkok',
#     'location': {'address': '9/99 Charoen Krung Road Bangkoleam',
#      'lat': 13.699344486153302,
#      'lng': 100.49998625108408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.699344486153302,
#        'lng': 100.49998625108408}],
#      'distance': 7000,
#      'postalCode': '10120',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['9/99 Charoen Krung Road Bangkoleam',
#       'พระนคร',
#       'กรุงเทพมหานคร 10120',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4bd5b1495631c9b6b27aa430',
#     'name': 'Chatrium Hotel Riverside Bangkok',
#     'location': {'address': '28 Soi Charoen Krung 70',
#      'lat': 13.710764961564532,
#      'lng': 100.51007509231567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.710764961564532,
#        'lng': 100.51007509231567}],
#      'distance': 7891,
#      'postalCode': '10120',
#      'cc': 'TH',
#      'city': 'บางคอแหลม',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['28 Soi Charoen Krung 70',
#       'บางคอแหลม',
#       'กรุงเทพมหานคร 10120',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '54853495'},
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4cdeb0b8abfb2c0fa2e69a5a',
#     'name': 'Suan Dusit Place Hotel (โรงแรมสวนดุสิตเพลส)',
#     'location': {'address': 'Suan Dusit University',
#      'crossStreet': 'Nakhon Ratchasima Rd',
#      'lat': 13.77575400414133,
#      'lng': 100.5110221941159,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.77575400414133,
#        'lng': 100.5110221941159}],
#      'distance': 10480,
#      'postalCode': '10300',
#      'cc': 'TH',
#      'city': 'ดุสิต',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Suan Dusit University (Nakhon Ratchasima Rd)',
#       'ดุสิต',
#       'กรุงเทพมหานคร 10300',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4b0587f6f964a5201fa922e3',
#     'name': 'The Montien Hotel Bangkok (โรงแรมมณเฑียร)',
#     'location': {'address': '54 Surawong Rd',
#      'lat': 13.731161713315615,
#      'lng': 100.53176132261765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.731161713315615,
#        'lng': 100.53176132261765}],
#      'distance': 10386,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['54 Surawong Rd',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '36958009'},
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4e03eb2162e1b12875a75ca1',
#     'name': 'Eastin Grand Hotel Sathorn',
#     'location': {'address': '33/1 Sathon Tai Rd',
#      'lat': 13.719062063967092,
#      'lng': 100.52174839823431,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.719062063967092,
#        'lng': 100.52174839823431}],
#      'distance': 9153,
#      'postalCode': '10120',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['33/1 Sathon Tai Rd',
#       'บางรัก',
#       'กรุงเทพมหานคร 10120',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823297',
#     'hasPerk': False},
#    {'id': '4b9b1d27f964a520b8f335e3',
#     'name': 'Pullman Bangkok Hotel G (โรงแรมพูลแมน กรุงเทพฯ จี)',
#     'location': {'address': '188 Silom Rd',
#      'lat': 13.725497609160316,
#      'lng': 100.52600249967614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.725497609160316,
#        'lng': 100.52600249967614}],
#      'distance': 9675,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['188 Silom Rd',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4bc1b29ab492d13a835ca660',
#     'name': 'Siam@Siam Design Hotel Bangkok',
#     'location': {'address': '865 Rama I Rd.',
#      'lat': 13.746995303168196,
#      'lng': 100.52694401649471,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.746995303168196,
#        'lng': 100.52694401649471}],
#      'distance': 10346,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['865 Rama I Rd.',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4b532366f964a520fd8f27e3',
#     'name': 'Narai Hotel (โรงแรมนารายณ์)',
#     'location': {'address': '222 Silom Rd.',
#      'lat': 13.725607006192,
#      'lng': 100.52447855472565,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.725607006192,
#        'lng': 100.52447855472565}],
#      'distance': 9513,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['222 Silom Rd.',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4b0587f6f964a52026a922e3',
#     'name': 'Eastin Hotel Makkasan Bangkok',
#     'location': {'address': '1091/343 Nikhom Makkasan Rd.',
#      'crossStreet': 'at Soi Charurat',
#      'lat': 13.753667119954354,
#      'lng': 100.54666686698914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.753667119954354,
#        'lng': 100.54666686698914}],
#      'distance': 12603,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'ราชเทวี',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['1091/343 Nikhom Makkasan Rd. (at Soi Charurat)',
#       'ราชเทวี',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4bbefaf8006dc9b6eddefb3f',
#     'name': 'ibis Bangkok Sathorn Hotel',
#     'location': {'address': '29/9 Soi Ngam Du Phli',
#      'lat': 13.721614481356019,
#      'lng': 100.54659969271684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.721614481356019,
#        'lng': 100.54659969271684}],
#      'distance': 11853,
#      'postalCode': '10120',
#      'cc': 'TH',
#      'city': 'สาทร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['29/9 Soi Ngam Du Phli',
#       'สาทร',
#       'กรุงเทพมหานคร 10120',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4ba4ec4ef964a5208ac338e3',
#     'name': 'Grand Sukhumvit Hotel Bangkok',
#     'location': {'address': '99 Sukhumvit 6',
#      'crossStreet': 'Sukhumvit Soi 6',
#      'lat': 13.739063188693393,
#      'lng': 100.55458911448646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.739063188693393,
#        'lng': 100.55458911448646}],
#      'distance': 12978,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'คลองเตย',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['99 Sukhumvit 6 (Sukhumvit Soi 6)',
#       'คลองเตย',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4b5df34cf964a5209c7529e3',
#     'name': 'Arnoma Grand Hotel Bangkok',
#     'location': {'address': '99 Ratchadamri Rd.',
#      'lat': 13.74681193915922,
#      'lng': 100.54065534274112,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.74681193915922,
#        'lng': 100.54065534274112}],
#      'distance': 11741,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['99 Ratchadamri Rd.',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '50b054cae4b0441cd8e7a7ab',
#     'name': 'Prime Hotel Central Station Bangkok (โรงแรม ไพร์ม เซ็นทรัลสเตชั่น)',
#     'location': {'address': '23/34-35 Soi Sukhon 1',
#      'lat': 13.737535326407839,
#      'lng': 100.51538989904603,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.737535326407839,
#        'lng': 100.51538989904603}],
#      'distance': 8826,
#      'postalCode': '10100',
#      'cc': 'TH',
#      'neighborhood': 'Samphan',
#      'city': 'สัมพันธวงศ์',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['23/34-35 Soi Sukhon 1',
#       'สัมพันธวงศ์',
#       'กรุงเทพมหานคร 10100',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4bf7e18392d19521701d5a1f',
#     'name': 'Royal Hotel (โรงแรมรัตนโกสินทร์)',
#     'location': {'address': 'Ratchadamnoen Klang Rd.',
#      'lat': 13.757138052117332,
#      'lng': 100.49543817078101,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.757138052117332,
#        'lng': 100.49543817078101}],
#      'distance': 7869,
#      'postalCode': '10200',
#      'cc': 'TH',
#      'city': 'Pra Nakorn',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Ratchadamnoen Klang Rd.',
#       'Pra Nakorn',
#       'กรุงเทพมหานคร 10200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4f39a790e4b0eebd6ba86024',
#     'name': 'Chaydon Sathorn Hotel (โรงแรมเชดอนสาทร)',
#     'location': {'address': '31 Sathon Tai Rd',
#      'lat': 13.723829750043471,
#      'lng': 100.53823216933189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.723829750043471,
#        'lng': 100.53823216933189}],
#      'distance': 10970,
#      'postalCode': '10120',
#      'cc': 'TH',
#      'city': 'สาทร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['31 Sathon Tai Rd',
#       'สาทร',
#       'กรุงเทพมหานคร 10120',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4d0629a09d33a1438ac7c478',
#     'name': 'Bangkok City Hotel (โรงแรมบางกอกซิตี้)',
#     'location': {'address': '268 Petchburi Rd.',
#      'crossStreet': 'btwn Petchburi 10-12',
#      'lat': 13.754248334420591,
#      'lng': 100.5287996972949,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.754248334420591,
#        'lng': 100.5287996972949}],
#      'distance': 10836,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'ราชเทวี',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['268 Petchburi Rd. (btwn Petchburi 10-12)',
#       'ราชเทวี',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False},
#    {'id': '4b6e7458f964a5200ebe2ce3',
#     'name': 'Miramar Hotel Bangkok',
#     'location': {'address': '777 Mahachai Rd',
#      'lat': 13.747213337298332,
#      'lng': 100.50326774302918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.747213337298332,
#        'lng': 100.50326774302918}],
#      'distance': 8005,
#      'postalCode': '10200',
#      'cc': 'TH',
#      'city': 'วังบูรพาภิรมย์',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['777 Mahachai Rd',
#       'วังบูรพาภิรมย์',
#       'กรุงเทพมหานคร 10200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550823298',
#     'hasPerk': False}]}}

# %%
len(search_results['response']['venues'])
# Out:
# 30

# %% [markdown]
# Let's check how many fields we have per response.

# %%
search_results['response']['venues'][0].keys()
# Out:
# dict_keys(['id', 'name', 'location', 'categories', 'venuePage', 'referralId', 'hasPerk'])

# %%
search_results['response']['venues'][0]
# Out:
# {'id': '4b0587f6f964a5200da922e3',
#  'name': 'Shangri-La Hotel, Bangkok',
#  'location': {'address': '89 Soi Charoen Krung 42/1',
#   'lat': 13.721573379038752,
#   'lng': 100.51381182368625,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 13.721573379038752,
#     'lng': 100.51381182368625}],
#   'distance': 8317,
#   'postalCode': '10500',
#   'cc': 'TH',
#   'city': 'บางรัก',
#   'state': 'กรุงเทพมหานคร',
#   'country': 'ประเทศไทย',
#   'formattedAddress': ['89 Soi Charoen Krung 42/1',
#    'บางรัก',
#    'กรุงเทพมหานคร 10500',
#    'ประเทศไทย']},
#  'categories': [{'id': '4bf58dd8d48988d1fa931735',
#    'name': 'Hotel',
#    'pluralName': 'Hotels',
#    'shortName': 'Hotel',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#     'suffix': '.png'},
#    'primary': True}],
#  'venuePage': {'id': '32930345'},
#  'referralId': 'v-1550823297',
#  'hasPerk': False}

# %% [markdown]
# ### Neighborhood check - number of hotels per neighborhood

# %% [markdown]
# let's check how many hotels we have in each neighborhood. The method is flawed because the search has to be per radius and related to the latlon points we got from the initial dataframe, which are not that great - however let's try to find a viable results anyway.

# %% [markdown]
# Step 1 - build a new dataframe with hotels associated to neighborhood.

# %%
venues = search_results['response']['venues']
hotels_list = json_normalize(venues)

# filter columns
filtered_columns = ['id', 'name', 'location.address', 'location.lat', 'location.lng', 'Neighborhood']
hotels_list_b = hotels_list.loc[:, filtered_columns]

hotels_list_b.head()

for venue in venues:
    print(venue['location']['address'])
# Out:
# 89 Soi Charoen Krung 42/1
# 946 Rama IV Rd
# 991/9 Rama I Rd
# 257 Charoen Nakhon Rd
# 61 Wireless Road (Witthayu), Lumpini, Pathumwan, Bangkok
# 518/8 Ploenchit Road, Lumphini
# 222 Ratchaprarop Rd
# 4 Sukhumvit Road, Khlong Toei
# 29 Sukhumvit 3
# 2 Charoen Krung 30
# 444 Phaya Thai Rd
# 1091/336 Phetchaburi Rd
# 143
# 9/99 Charoen Krung Road Bangkoleam
# 28 Soi Charoen Krung 70
# Suan Dusit University
# 54 Surawong Rd
# 33/1 Sathon Tai Rd
# 188 Silom Rd
# 865 Rama I Rd.
# 222 Silom Rd.
# 1091/343 Nikhom Makkasan Rd.
# 29/9 Soi Ngam Du Phli
# 99 Sukhumvit 6
# 99 Ratchadamri Rd.
# 23/34-35 Soi Sukhon 1
# Ratchadamnoen Klang Rd.
# 31 Sathon Tai Rd
# 268 Petchburi Rd.
# 777 Mahachai Rd
# C:\Users\Marco.M\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %% [markdown]
# Now let's serialize the process for all the neighborhoods

# %%
def getHotels(hoods, latitudes, longitudes, LIMIT=50, radius=500):
    
    hotels_list = []
    
    for hood, lat, lng in zip(hoods, latitudes, longitudes):
        print(hood, lat, lng)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&categoryId=4bf58dd8d48988d1fa931735&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        
        #categoryId=4bf58dd8d48988d1fa931735
            
        # make the GET request
        results = requests.get(url).json()
        hotel_response = results['response']['venues']
        
        for i in range(len(hotel_response)):
                hotels_list.append([
                hood, 
                lat, 
                lng,
                hotel_response[i]['id'], 
                hotel_response[i]['name'],
                hotel_response[i]['location']['lat'],
                hotel_response[i]['location']['lng']])
                
    columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue Id',
                  'Venue Name',
                  'Venue Latitude', 
                  'Venue Longitude']
    
    hotels = pd.DataFrame(columns=columns)
    for i in range(len(hotels_list)):
        hotels.loc[i] = [hotel for hotel in hotels_list[i]]
    
    return(hotels)

# %%
bkk_hotels = getHotels(hoods=df['Neighborhood'],
                       latitudes=df['latitude'],
                       longitudes=df['longitude']
                       )
# Out:
# Bang Kapi 13.765832999999999 100.647778
# Bang Khae 13.696110999999998 100.409444
# Bang Khen 13.873889000000002 100.596389
# Bang Kho Laem 13.693332999999999 100.5025
# Bang Khun Thian 13.660832999999998 100.435833
# Bang Na 13.680081 100.5918
# Bang Phlat 13.793889000000002 100.505
# Bang Rak 13.730832999999999 100.524167
# Bang Sue 13.809722 100.537222
# Bangkok Noi 13.770867 100.467933
# Bangkok Yai 13.722778 100.476389
# Bueng Kum 13.785278 100.669167
# Chatuchak 13.828610999999999 100.559722
# Chom Thong 13.677222 100.48472199999999
# Din Daeng 13.769722 100.552778
# Don Mueang 13.913610999999998 100.589722
# Dusit 13.776944 100.520556
# Huai Khwang 13.776667000000002 100.579444
# Khlong Sam Wa 13.859722 100.704167
# Khlong San 13.730278 100.509722
# Khlong Toei 13.708056 100.583889
# Lak Si 13.8875 100.578889
# Lat Krabang 13.722317000000002 100.75966899999999
# Lat Phrao 13.803610999999998 100.6075
# Min Buri 13.813889000000001 100.748056
# Nong Chok 13.855556 100.8625
# Nong Khaem 13.704722 100.348889
# Pathum Wan 13.744942000000002 100.5222
# Phasi Charoen 13.714722 100.43722199999999
# Phaya Thai 13.78 100.542778
# Phra Khanong 13.702222 100.601667
# Phra Nakhon 13.764444000000001 100.499167
# Pom Prap Sattru Phai 13.758056 100.513056
# Prawet 13.716944 100.69444399999999
# Rat Burana 13.682222 100.505556
# Ratchathewi 13.758889000000002 100.534444
# Sai Mai 13.919167000000002 100.645833
# Samphanthawong 13.731389000000002 100.514167
# Saphan Sung 13.77 100.684722
# Sathon 13.708056 100.526389
# Suan Luang 13.730278 100.651389
# Taling Chan 13.776944 100.45666700000001
# Thon Buri 13.725 100.485833
# Watthana 13.742222 100.585833
# Yan Nawa 13.696944 100.543056

# %% [markdown]
# Let's drop duplicates.

# %%
bkk_hotels = bkk_hotels.drop_duplicates(subset='Venue Id', keep='first')
bkk_hotels
# Out:
#         Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0          Bang Kapi              13.765833              100.647778
# 1          Bang Kapi              13.765833              100.647778
# 2          Bang Kapi              13.765833              100.647778
# 3          Bang Kapi              13.765833              100.647778
# 4          Bang Khen              13.873889              100.596389
# 5      Bang Kho Laem              13.693333              100.502500
# 6      Bang Kho Laem              13.693333              100.502500
# 7      Bang Kho Laem              13.693333              100.502500
# 8      Bang Kho Laem              13.693333              100.502500
# 9      Bang Kho Laem              13.693333              100.502500
# 10   Bang Khun Thian              13.660833              100.435833
# 11   Bang Khun Thian              13.660833              100.435833
# 12   Bang Khun Thian              13.660833              100.435833
# 13        Bang Phlat              13.793889              100.505000
# 14        Bang Phlat              13.793889              100.505000
# 15        Bang Phlat              13.793889              100.505000
# 16        Bang Phlat              13.793889              100.505000
# 17        Bang Phlat              13.793889              100.505000
# 18        Bang Phlat              13.793889              100.505000
# 19        Bang Phlat              13.793889              100.505000
# 20        Bang Phlat              13.793889              100.505000
# 21          Bang Rak              13.730833              100.524167
# 22          Bang Rak              13.730833              100.524167
# 23          Bang Rak              13.730833              100.524167
# 24          Bang Rak              13.730833              100.524167
# 25          Bang Rak              13.730833              100.524167
# 26          Bang Rak              13.730833              100.524167
# 27          Bang Rak              13.730833              100.524167
# 28          Bang Rak              13.730833              100.524167
# 29          Bang Rak              13.730833              100.524167
# ..               ...                    ...                     ...
# 336   Samphanthawong              13.731389              100.514167
# 342   Samphanthawong              13.731389              100.514167
# 344   Samphanthawong              13.731389              100.514167
# 345   Samphanthawong              13.731389              100.514167
# 348   Samphanthawong              13.731389              100.514167
# 349   Samphanthawong              13.731389              100.514167
# 352           Sathon              13.708056              100.526389
# 353           Sathon              13.708056              100.526389
# 354           Sathon              13.708056              100.526389
# 355           Sathon              13.708056              100.526389
# 356           Sathon              13.708056              100.526389
# 357       Suan Luang              13.730278              100.651389
# 358       Suan Luang              13.730278              100.651389
# 359      Taling Chan              13.776944              100.456667
# 360      Taling Chan              13.776944              100.456667
# 361        Thon Buri              13.725000              100.485833
# 362         Watthana              13.742222              100.585833
# 363         Watthana              13.742222              100.585833
# 364         Watthana              13.742222              100.585833
# 365         Watthana              13.742222              100.585833
# 366         Watthana              13.742222              100.585833
# 367         Watthana              13.742222              100.585833
# 368         Watthana              13.742222              100.585833
# 369         Watthana              13.742222              100.585833
# 370         Watthana              13.742222              100.585833
# 371         Watthana              13.742222              100.585833
# 372         Watthana              13.742222              100.585833
# 373         Yan Nawa              13.696944              100.543056
# 374         Yan Nawa              13.696944              100.543056
# 375         Yan Nawa              13.696944              100.543056
#
#                      Venue Id                                     Venue Name  \
# 0    58ceb8c2ef469468c98052e2                               The Pantip Hotel
# 1    4df90af2483bc58a610bc092                                 Peep Inn Hotel
# 2    518ff1f4498e36d160a6fd65                   Mall Inn Hotel Lad Phrao 144
# 3    518ede52498e5714a820d674                    Mall Inn Hotel ลาดพร้าว 144
# 4    4f78ea7ce4b0b9643bc9b5ec                                 B8 Rooms Hotel
# 5    4e0fc9547d8bb178a8b67710       Gym & Swimming Pool @ Charoenkrung Place
# 6    513e3d7ce4b0bb777c93904a                           โรงแรมแม่นํ้า รามาดา
# 7    4de4a78445dd180ae57a1422                                  Vivi's Room 
# 8    4d7364a2f7c38cfa8248b63d                 Bangkok Marriot Resort and Spa
# 9    4e4efa48aeb70f12849a835d                                     Forum park
# 10   4ca2c48af832a1cd621d98e5                                   Park Village
# 11   50c878c1e4b062eca526fbb4                                     Maxx hotel
# 12   4da566decda1c55f755530a8                                  Ban Chom Duan
# 13   530e4be811d2d1af47f97807                             Beyond Suite Hotel
# 14   53648dfb498ed20936c06415                             โรงแรมบียอนด์ สวีท
# 15   4e4b92bcfa7671a85ceafa0f                         โรงแรม ลักษ์ซัวรี่สวีท
# 16   4f711dd8e4b037626f17051e                            โรงแรมลักษ์ชัวร์รี่
# 17   5087d130e4b0c4120efd9079                       โรงแรมบียอนด์ เขตบางพลัด
# 18   51a39081498e034ce287fa9d  Luxury Suite Hotel (โรงแรมลักษ์ชัวร์รี่ สวีท)
# 19   4e3e6c59aeb73139a1863ae8                               Resort Bangphlat
# 20   55f7f06d498e8f63ece297a8                        มาย รีสอร์ท แอท ริเวอร์
# 21   5b93bc11dd70c500391425c2                            Simply Sleep Hostel
# 22   4dc2e331fa7608e86fe4771b                                       BED time
# 23   5624f5ac498e229670f8d50a                  Amara Bangkok (อัมรา กรุงเทพ)
# 24   567fa4a5498edbf19b5f842e                            The Backpack Hostel
# 25   4d61f301d7206ea8972706f2                           Money Room Apartment
# 26   4bd0f78320cd996084962e9e              Royal Asia Paradise Hotel Bangkok
# 27   5acd777b2f97ec1babbd9f2d           Swimming Pool At Marriott Surawangse
# 28   4d31a87b5017a093ff4d419b                                  Lod.D Bangkok
# 29   5a1bc39cfe37405daae10cad          Bangkok Marriott Hotel The Surawongse
# ..                        ...                                            ...
# 336  51d9169e498e2083ac95a3db                             Poste 43 Residence
# 342  4dc028184df0f8fd6b963244                                            ibO
# 344  587109f99c439d43ab33e3e7                                      Folktel39
# 345  59991a1eda5e5606a941b8fb                                      Marin Inn
# 348  568fb1c7498e9d5aa2aee039   Bangkok Centre Hotel (โรงแรมบางกอกเซ็นเตอร์)
# 349  56a75e8f498efc7b2715d8d3                                  Bangkok Story
# 352  4e5fbc908877694559e0984d                      Winsor Suites Hotel #2818
# 353  50d29f6ce4b05fc2cdc2e752                                 พนธ์นทีรีสอร์ท
# 354  4cc5047901fb236a0468afba                                         หอโอเค
# 355  5b1a5784f1fdaf002c9bb81c                                 Charles Hostel
# 356  4d3b5324bf6d5481f1f8d5e1                       Pak-Chong Landmark Hotel
# 357  5a886bcec97f285cf605d1eb                                      Hcube Bkk
# 358  4f06c6c0e4b000dd73a43f1c                                      พัฒาการ51
# 359  595646d08a6f17723fc27365                                  บ้านเจ็ทลู้วว
# 360  4d3702550a0b721e54f6969b                                 ploy's bedroom
# 361  581d7dae69b32f2133bc3115                                         Zenniq
# 362  570a8058498e43767b383b0b                                      Metropole
# 363  4f863c75e4b09a251da498d9                            A-One Hotel Bkk-Pty
# 364  4c9f6025d3c2b60c09c9d3bc                                    Petch Tower
# 365  4ef8c13d9adf7bbf89b3f9ad                             All Season Sathorn
# 366  5684d42b498e4d8e6fe9897c                      the Residence on Thonglor
# 367  5205f7a211d26505e06d24f4              Demeter Residences Suites Bangkok
# 368  4be1975a8dd062b55d663e3c                      Union Tower Hotel Bangkok
# 369  4c79dbcd794e224bfc226728                                The Green Bells
# 370  4cccddcd511b236ab042f4c9     A-ONE Bangkok Hotel (โรงแรมเอ-วัน กรุงเทพ)
# 371  5ae07a3fc4df1d0b7691f4ab                                 MADCAT BANGKOK
# 372  5a081443a3061903b86d72d7      Holiday Inn Express Bangkok Soi Soonvijai
# 373  4c83e311d8086dcb900a8452                              S.K.Grand Sathorn
# 374  4f790a51e4b0e0abc5e746f1            โรงแรมแกรนด์ เซ็นเตอร์พอยท์ ราชดำริ
# 375  4cc991ba5c17b60c29e80905                      Lumpini Place Water Cliff
#
#      Venue Latitude  Venue Longitude
# 0         13.766296       100.645489
# 1         13.763555       100.650416
# 2         13.766454       100.643690
# 3         13.766504       100.643558
# 4         13.870801       100.593676
# 5         13.693619       100.500752
# 6         13.693803       100.505441
# 7         13.691904       100.502248
# 8         13.689827       100.502746
# 9         13.693858       100.507046
# 10        13.661428       100.434087
# 11        13.660513       100.436752
# 12        13.661542       100.440402
# 13        13.795153       100.506846
# 14        13.795357       100.506387
# 15        13.795335       100.506556
# 16        13.793621       100.507515
# 17        13.795496       100.506560
# 18        13.795418       100.506689
# 19        13.790587       100.502335
# 20        13.790160       100.505969
# 21        13.729053       100.523910
# 22        13.731051       100.523282
# 23        13.728384       100.528779
# 24        13.729641       100.524511
# 25        13.732391       100.525266
# 26        13.733176       100.520254
# 27        13.727261       100.522320
# 28        13.729285       100.523351
# 29        13.727207       100.522344
# ..              ...              ...
# 336       13.727972       100.516448
# 342       13.734746       100.517735
# 344       13.729435       100.516881
# 345       13.734709       100.514733
# 348       13.736591       100.516234
# 349       13.735952       100.512773
# 352       13.708828       100.525017
# 353       13.706099       100.527222
# 354       13.710411       100.530520
# 355       13.705560       100.524262
# 356       13.712829       100.527060
# 357       13.732486       100.647040
# 358       13.733164       100.647727
# 359       13.772679       100.459099
# 360       13.776285       100.452550
# 361       13.722598       100.489920
# 362       13.743708       100.585748
# 363       13.741460       100.585029
# 364       13.742017       100.587924
# 365       13.744001       100.590294
# 366       13.739331       100.584371
# 367       13.744209       100.583413
# 368       13.744833       100.587003
# 369       13.743892       100.590115
# 370       13.746954       100.587203
# 371       13.736631       100.585199
# 372       13.747693       100.584608
# 373       13.698412       100.542849
# 374       13.698680       100.543101
# 375       13.699543       100.538341
#
# [357 rows x 7 columns]

# %% [markdown]
# Which neighborhoods have the most hotels?

# %%
hotels_grouped = bkk_hotels.groupby('Neighborhood')['Venue Name'].count().sort_values(axis=0, ascending=False).to_frame().reset_index()
hotels_grouped = hotels_grouped.rename(columns={'Venue Name':'Hotels'})
hotels_grouped.head()
# Out:
#   Neighborhood  Hotels
# 0  Phra Nakhon      50
# 1  Ratchathewi      49
# 2     Bang Rak      45
# 3  Huai Khwang      21
# 4   Khlong San      21

# %% [markdown]
# Which neighborhoods have the least hotels?

# %%
hotels_grouped.tail()
# Out:
#      Neighborhood  Hotels
# 30  Khlong Sam Wa       1
# 31       Min Buri       1
# 32        Sai Mai       1
# 33      Thon Buri       1
# 34      Bang Khen       1

# %% [markdown]
# In order to understand why there is such a difference between these neighborhoods, let's try to understand what makes these datapoints so unique. How can we do it?

# %%
# Let's create a map with all the hotels we found.
# add markers to map
for lat, lng, neighbourhood, hotel_name in zip(bkk_hotels['Venue Latitude'], bkk_hotels['Venue Longitude'], bkk_hotels['Neighborhood'], bkk_hotels['Venue Name']):
    label = '{}, {}'.format(neighbourhood, hotel_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(bkk)  
    
bkk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From the map above we can see that hotels are clustered in a few spots - mainly around the initial datapoints.

# %% [markdown]
# How can we check what are the similarities between the various areas?
#
# We will adopt a simplified approach:
#
#     * Find the most common traits among hotels
#     * Find an area which has all these traits

# %%
def getNearbyVenues(names, latitudes, longitudes, LIMIT=100, radius=500):
    import time
    
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        time.sleep(2)
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        
        #print(url)
        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        if results is None:
            pass
        else:
            venues_list.append([(
                name, 
                lat, 
                lng, 
                v['venue']['name'], 
                v['venue']['location']['lat'], 
                v['venue']['location']['lng'],  
                v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
hotel_clusters = getNearbyVenues(names=bkk_hotels['Venue Name'],
                                   latitudes=bkk_hotels['Venue Latitude'],
                                   longitudes=bkk_hotels['Venue Longitude']
                                  )
# Out:
# The Pantip Hotel
# Peep Inn Hotel
# Mall Inn Hotel Lad Phrao 144
# Mall Inn Hotel ลาดพร้าว 144
# B8 Rooms Hotel
# Gym & Swimming Pool @ Charoenkrung Place
# โรงแรมแม่นํ้า รามาดา
# Vivi's Room 
# Bangkok Marriot Resort and Spa
# Forum park
# Park Village
# Maxx hotel
# Ban Chom Duan
# Beyond Suite Hotel
# โรงแรมบียอนด์ สวีท
# โรงแรม ลักษ์ซัวรี่สวีท
# โรงแรมลักษ์ชัวร์รี่
# โรงแรมบียอนด์ เขตบางพลัด
# Luxury Suite Hotel (โรงแรมลักษ์ชัวร์รี่ สวีท)
# Resort Bangphlat
# มาย รีสอร์ท แอท ริเวอร์
# Simply Sleep Hostel
# BED time
# Amara Bangkok (อัมรา กรุงเทพ)
# The Backpack Hostel
# Money Room Apartment
# Royal Asia Paradise Hotel Bangkok
# Swimming Pool At Marriott Surawangse
# Lod.D Bangkok
# Bangkok Marriott Hotel The Surawongse
# Mandarin Hotel (โรงแรมแมนดาริน)
# Swimming Pool
# iSanook Hostel (ไอสนุก โฮสเทล)
# Bed By City Surawong - Patpong
# La Residence Bangkok
# Everyday Bangkok Hostel
# HOFT Hostel
# The Lobby Lounge Marriott Surawongse
# Luxx Hotel
# Amara Bangkok Pool Bar
# Amara Bangkok
# Red Planet Surawong
# Grand Ballroom @ Mandarin Hotel
# iSanook Residence
# kokotel
# Newwaitek
# Lub d Bangkok - Silom
# T.T. guesthouse
# Yindee Hostel (ยินดีโฮสเทล)
# Executive Luxury Room
# รร สี่พระยาทาวเวอร์อินน์
# iWut's Pillows
# Prince Palace Hotel @ Prince Ballroom 3
# I SLEEP SILOM Hostel (I-Sleep Silom Hostel)
# Naratel Hostel Bangkok
# Lub d Bangkok - Surawong
# โรงแรมใจ F313
# Shadow Inn
# PLUBPLA Hostel
# The Blast Silom Hostel
# บ้านป้าสุณี
# A’stel Bangruk
# Sofetel Bangkok
# นารายณ์แกรนด์บอลรูม
# China Guest İnn
# park place samyan
# Sleepover Hostel
# Green Leafy Butique Lodge Bangkok
# Baan TalatPhlu
# Sivalai Place
# Birdy Swimming Pool @ Home
# President Park Suites Bangkok
# Ratchavipa Residence (รัชวิภาเรสซิเด้นซ์)
# Baan Mina
# Serene Bangkok Bed & Breakfast
# Northgate Ratchayothin
# Allanoot Hotel
# แหล่พักพิง
# โรงแรมแกนด์
# Room 1330 Princeton Park
# Princeton Bangkok
# Big Smile Hostel
# D-Well Residence@Donmuang
# โรงแรม ปริ้นตัน ดินแดง
# Kangvan Mansion Donmuang
# Domingo Hostel Donmueang
# Montri resort&spa
# Hoppers
# Mont Place
# Max One House
# Gold Tulip hotel
# บ้านตากะยาย@เชียงคาน
# Atrium Boutique Resort Hotel
# Ratchada City Hotel (โรงแรม รัชดาซิตี้)
# CY Service Apartment
# Guyasuka
# Ratchada City Hotel
# My Ratchada Hotel CMYK
# Amaranta Hotel
# MeStyle Garage Hotel Bangkok
# Private Resort
# Praso  @ Ratchada 12 Hotel Bangkok
# Level 7, Ratchada City Hotel
# โรงแรมรัชดา ซิตี้
# OBroom
# オアシスホテル
# อาหารเช้าymck
# โอเอซิส โฮเตล
# Bjoern's Vogel Palace
# Green room @ My Hotel
# Banya Hostel
# รัชดาแมนชั่น
# Yim Huai Khwang Hostel
# One O One
# Millennium Hilton Bangkok
# Thonburi Ballroom
# Eforea spa
# Swimming Pool
# 1117 Millenium Hotel Bangkok
# Royal Orchid Sheraton Hotel & Towers (โรงแรมรอยัลออคิดเชอราตัน)
# Terrace Pool
# Jacuzzi room 2724
# Ball Room
# Meeting RoomMillennium Hilton
# The Royal Suite
# Riverside Ballroom
# Pompadour Room
# Garden Pool
# The St. Regis Bangkok: Pre-opening Office
# Front Office
# Amdaeng Hotel
# Tiny Taladnoi Hostel
# River View Guest House
# Loy La Long Hotel (ลอยละล่อง)
# Petit hostel
# ibis Styles Bangkok Sukhumvit 50
# The Standard Hotel
# Mida City Resort (ไมด้า ซิตี้ รีสอร์ท)
# Casa Residence
# Wayha Hostel
# SP Airport Hotel
# Learn Phraya Suvarnabhumi (เรือนพระยา สุวรรณภูมิ)
# Convenient Resort
# Wanderlust Hostel Bangkok
# KRISS AIRPORT RESIDENCE
# SK court
# The Villa Resort
# SB_PLACE
# คุ้มเกล้า ทีค ฮัท รีสอร์ท
# Cubic Bangkok Hostel
# Tongpoon Hotel (โรงแรมทองพูน)
# Twin plaza
# Tongpoon Hotel
# Tong Poon Hotel
# 168 Hostel
# King Tong @ Asian Hotel
# Swimming Pool
# Room 1263
# The Twin Towers Hotel
# ภูไอยรา รีสอร์ท
# Lazy Sunday (เลซี่ซันเดย์)
# Siam Stadium Hostel (สยาม สเตเดียม โฮสเทล)
# House Of Papa
# City Residence Hotel
# PariyaVilla
# Swimming Pool LPN Saparnkwai
# CIAO HOSTEL
# Lost&found hostel
# LAF Hotel
# REST Ari Hostel
# 19A Hostel
# Josh Hotel
# Vestel Aree
# The Yard (บ้านญาติ โฮสเทล)
# My Hotel
# Pathumwan Resort
# Tk Guesthouse
# unitato hostel
# My Temporary Hotel Stay Bangkok
# All Season Hotel สนามเป้า
# At Mind Executive Residence
# @Mind Executive Suites
# Baan Namtarn
# Avani Sukhumvit Bangkok (Construction Site)
# x2 vibe hotel
# Chateau De Sukhumvit
# Orchid Resort
# s31 สุขุมวิท 31
# K79Room
# Qiu Hotel Sukhumvit 79
# Ak House
# Imm Fusion 4th Floor
# Baan Cedarberg
# chateau 59
# อิม ฟิวชั่น ^ ^
# Viva Garden Serviced Residence
# Hostel 24
# The Green Bells On-Nut
# Tara Place Hotel
# Born Free Hostel
# Khaosan Immjai (ข้าวสารอิ่มใจ เกสท์เฮ้าส์)
# Rajata Hotel (โรงแรมรัชตะ)
# The Orchid House 153
# Q6 at 6 Hostel
# Let’s Zzz Hotel
# Nouvo City Hotel (โรงแรมนูโวซิตี้)
# Baan Bangkok Hostel & Cafe
# Saran Hotel
# Casa Nithra Hotel
# Chillax Resort
# Mad Monkey Bangkok
# Blue House by the Chang
# Casa Vimaya Riverside (คาซ่า วิมายา ริเวอร์ไซด์)
# MINT HOSTEL
# Fortville Guesthouse (ฟอร์ทวิลล์ เกสท์เฮาส์)
# Dewan Bangkok (เดวาน)
# Sloth Hostel (สล็อธ โฮสเทล)
# Counting Stars Hostel
# Apple Guesthouse No. 2
# Lost Inn Bkk
# Flapping Duck Guesthouse
# Long luck guesthouse
# Bella Bella Riverview Guesthouse
# Bed Spread Hostel
# Lida 1946
# Rambuttri Village Inn & Plaza
# Lamphu House
# Roof View Place (รูฟวิว เพลส)
# Bed Station Hostel
# Trang Hotel (โรงแรมตรัง)
# Oasis Hostel
# Oh Bangkok Hostel
# The Lol Elephant Hostel
# Samsen 360 Hostel
# sabyi bangkok
# 3 HOWw Hostel
# Villa Cha-Cha Hotel
# Baan Nampetch Hostel
# Adamaz House (อดามาซ เฮ้าส์)
# Swana Bangkok Hotel
# Suneta Hostel (สุเนต์ตา)
# NACORN Hostel
# Trang Hotel Pool
# Sleep Withinn
# NapPark Hostel
# Warm White Hostel (วอมไวท์โฮสเทล)
# Green House
# Lamphu Tree House Boutique Hotel
# Royal Princess Larn Luang (รอยัล ปริ้นเซส หลานหลวง)
# Loog Choob Homestay (ลูกชุบ โฮมสเตย์)
# กองสลาก Sawasdee Khaosan Inn18 Chakkapong Road Bangkok, Thailand￼⁠
# Kanvela House (กาลเวลาเฮ้าส์)
# Bed & Butler Hostel (เบด แอนด์ บัตเลอร์)
# รร.เพลิน 89 ถ.หลานหลวง
# Smile Inn
# โรงแรมลายทอง
# The Seven Luck
# Green Hotel (โรงแรมกรีนโฮเท็ล)
# ห้องประชุมราชา1-2 ปริ้นซ์าพาเลซ
# Масин рай
# บ้านก้อยดาว
# โรงแรมสมานมิตร
# Prince Palace Hotel (โรงแรมปรินซ์พาเลซ)
# The Region Hotel
# Windy City
# Summit Pavillion
# Love and Care Pet
# PP One Swimming Pool
# Florida Hotel (โรงแรมฟลอริด้า)
# The Sukosol (โรงแรม เดอะ สุโกศล)
# Hotel 99 (โรงแรมพญาไท 99)
# Sukhon Hotel
# Swimming Pool
# 99โฮเต็ล
# True Siam Hotel
# โรงแรมฟลอริดา
# My Hotel
# Hotel Tranz
# L'hôtel de 99 Phayathai
# ห้องอาหารเช้า เดอะสุโกศล
# Rabitat
# Pullman King Power Suite Room 1725
# Kamolruedi Siam City Hotel
# Lobby Lounge @ Siam City Hotel
# Tarawish Hotel
# Pullman Bangkok King Power
# Top High Airport Link
# Anajak Bangkok Hotel (โรงแรม อาณาจักร แบงค์ค็อก)
# Cloudy Hostel
# Lobby
# Sleep Lab Hostel
# The Victory Executive Residences
# motel กรุงไทย ม่านรูด
# ห้องกมลพร
# Swimming Pool
# Noursabah
# The Posh
# จุดรับส่งของโรงแรมพูลแมนคิงเพาเวอร์กรุงเทพ
# Yellow Mango Hostel
# In a Box Hostel
# Rabbitat Hostel & Café
# Cubic Pratunam
# Swimming Pool Anajak
# Dream Town Hotel
# Cubic Hotel
# Lemonseed Rooms
# Siam Journey Guesthouse
# ps mentro
# Locker room (Best western mayfair suites hotel)
# Swimming pool
# iCheckinn Mayfair Hotel
# Lobby at FIRST HOTEL
# เพชรบุรี อพาร์ตเม้น ซอย7
# Vimarn Hostel (วิมานโฮสเทล)
# 5 Minute Hostel
# apera hotel
# opera swimming pool
# AB Resort
# Bunny Burrow Hostel
# Talakkia Boutique Hotel
# Oldtown Hostel
# ซอยกัปตันบุช
# Loftel 22 Hostel
# Fun Café and Hostel Bangkok (ฝัน คาเฟ่และโฮสเทล)
# The Chilli Bangkok
# urban hostel bangkok
# Car park opposite bangkok bank,talad noi
# Poste 43 Residence
# ibO
# Folktel39
# Marin Inn
# Bangkok Centre Hotel (โรงแรมบางกอกเซ็นเตอร์)
# Bangkok Story
# Winsor Suites Hotel #2818
# พนธ์นทีรีสอร์ท
# หอโอเค
# Charles Hostel
# Pak-Chong Landmark Hotel
# Hcube Bkk
# พัฒาการ51
# บ้านเจ็ทลู้วว
# ploy's bedroom
# Zenniq
# Metropole
# A-One Hotel Bkk-Pty
# Petch Tower
# All Season Sathorn
# the Residence on Thonglor
# Demeter Residences Suites Bangkok
# Union Tower Hotel Bangkok
# The Green Bells
# A-ONE Bangkok Hotel (โรงแรมเอ-วัน กรุงเทพ)
# MADCAT BANGKOK
# Holiday Inn Express Bangkok Soi Soonvijai
# S.K.Grand Sathorn
# โรงแรมแกรนด์ เซ็นเตอร์พอยท์ ราชดำริ
# Lumpini Place Water Cliff

# %%
hotel_results = hotel_clusters

# %%
hotel_results.head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  The Pantip Hotel              13.766296              100.645489
# 1  The Pantip Hotel              13.766296              100.645489
# 2  The Pantip Hotel              13.766296              100.645489
# 3  The Pantip Hotel              13.766296              100.645489
# 4  The Pantip Hotel              13.766296              100.645489
#
#                                    Venue  Venue Latitude  Venue Longitude  \
# 0           Burger King (เบอร์เกอร์ คิง)       13.767083       100.643001
# 1  The Mall Bangkapi (เดอะมอลล์ บางกะปิ)       13.766983       100.642480
# 2                                    H&M       13.765972       100.642471
# 3                 Starbucks (สตาร์บัคส์)       13.767339       100.642136
# 4                 UNIQLO (ยูนิโคล่) ユニクロ       13.767217       100.642717
#
#          Venue Category
# 0  Fast Food Restaurant
# 1         Shopping Mall
# 2        Clothing Store
# 3           Coffee Shop
# 4        Clothing Store

# %%
cat_overview = hotel_results.groupby('Venue Category')['Venue'].count()
cat_overview = cat_overview.sort_values(axis=0, ascending=False).to_frame().reset_index()
cat_overview
# Out:
#                     Venue Category  Venue
# 0                            Hotel   1135
# 1                  Thai Restaurant   1029
# 2                     Noodle House    993
# 3                             Café    870
# 4                      Coffee Shop    694
# 5                Convenience Store    615
# 6                           Hostel    603
# 7                              Bar    541
# 8                 Asian Restaurant    539
# 9               Chinese Restaurant    520
# 10                      Restaurant    306
# 11                  Massage Studio    305
# 12             Japanese Restaurant    245
# 13                          Bakery    242
# 14              Seafood Restaurant    205
# 15            Fast Food Restaurant    205
# 16                      Steakhouse    194
# 17                    Dessert Shop    193
# 18                             Spa    190
# 19                       BBQ Joint    172
# 20                             Pub    168
# 21              Som Tum Restaurant    164
# 22              Italian Restaurant    154
# 23               Hotpot Restaurant    154
# 24                   Train Station    146
# 25                      Food Court    127
# 26                        Wine Bar    127
# 27   Vegetarian / Vegan Restaurant    122
# 28                Sushi Restaurant    121
# 29                Ramen Restaurant    118
# ..                             ...    ...
# 209                Warehouse Store      2
# 210             Athletics & Sports      1
# 211             Salon / Barbershop      1
# 212               Swiss Restaurant      1
# 213            Szechuan Restaurant      1
# 214                    Tailor Shop      1
# 215                         Temple      1
# 216             Turkish Restaurant      1
# 217            Arts & Crafts Store      1
# 218               Theme Restaurant      1
# 219               Recording Studio      1
# 220               Toy / Game Store      1
# 221                         Arcade      1
# 222                           Road      1
# 223                      Bike Shop      1
# 224                      Racetrack      1
# 225                      Pet Store      1
# 226          Performing Arts Venue      1
# 227                   Camera Store      1
# 228                         Palace      1
# 229                 Boarding House      1
# 230                Organic Grocery      1
# 231                     Nail Salon      1
# 232                          Motel      1
# 233                     Boxing Gym      1
# 234                      Mini Golf      1
# 235           Hong Kong Restaurant      1
# 236                 Hardware Store      1
# 237                      Cafeteria      1
# 238                    Yoga Studio      1
#
# [239 rows x 2 columns]

# %% [markdown]
# It appears that hotels are close to... hotels! This reinforces the theory that hotels kind of cluster together. What we should do now is find a suitable location, and find a location that is close to venues of specific categories. In this way we can target a specific clientele: a Japanese restaurant and an Onsen venue will attract Japanese customers, for example.
